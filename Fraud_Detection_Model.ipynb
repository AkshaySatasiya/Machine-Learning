# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing dataset 
df = pd.read_csv('C:/Users/akshay/Desktop/UFT/Task/dataset.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# __As we can see in the above inforamtion that there are no null or missing values present in the dataset so the dataset is good inough to go in the next step.__

# %% [markdown]
# ## Removing Outliers

# %%
sns.boxplot(y=df['Amount'])
plt.show()

# %%
sns.boxplot(y=df['Time'])
plt.show()

# %% [markdown]
# As we can see in the above boxplot that there is __no outlier present in the Time column__, but in Amount column there are some __outlier present above 9000.__
#
# So now we are going to remove that outliers

# %%
#Outliers
df.loc[df['Amount']>=9000]
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 46841    42951.0 -23.712839 -42.172688 -13.320825   9.925019  -13.945538
# 54018    46253.0 -21.780665 -38.305310 -12.122469   9.752791  -12.880794
# 58465    48401.0 -36.802320 -63.344698 -20.645794  16.715537  -20.672064
# 151296   95286.0 -34.549296 -60.464618 -21.340854  16.875344  -19.229075
# 169457  119713.0 -20.924897 -37.943452 -14.060281  10.473005  -10.866639
# 227921  145283.0 -21.532478 -34.704768  -8.303035  10.264175    3.957175
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
# 284249  172273.0  -9.030538 -11.112584 -16.233798   3.592021  -40.427726
#
#                V6          V7         V8        V9  ...        V21        V22  \
# 46841    5.564891   15.710644  -2.844253 -1.580725  ...   7.921600  -6.320710
# 54018    4.256017   14.785051  -2.818253 -0.667338  ...   7.437478  -5.619439
# ...

# %%
#Removing Outliers

df_new = df[df['Amount']<=9000]

# %% [markdown]
# ## Creating heatmap

# %%
plt.figure(figsize=(40,32))
sns.heatmap(df_new.corr(), fmt='.2g', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()

df_new['scaled_amount'] = std_scaler.fit_transform(df_new['Amount'].values.reshape(-1,1))
df_new['scaled_time'] = std_scaler.fit_transform(df_new['Time'].values.reshape(-1,1))

df_new.drop(['Time','Amount'], axis=1, inplace=True)

# %%
df_new
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
scaled_amount = df_new['scaled_amount']
scaled_time = df_new['scaled_time']

df_new.drop(['scaled_amount','scaled_time'], axis=1, inplace=True)
df_new.insert(0, 'scaled_amount', scaled_amount)
df_new.insert(1, 'scaled_time', scaled_time)

df_new.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       0.262062    -1.996583 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.362073    -1.996583  1.191857  0.266151  0.166480  0.448154
# 2       1.234987    -1.996562 -1.358354 -1.340163  1.773209  0.379780
# 3       0.151108    -1.996562 -0.966272 -0.185226  1.792993 -0.863291
# 4      -0.076194    -1.996540 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %% [markdown]
# hTe __"time"__ and __"amount"__ columns were observed to have different scales compared to other features. To solve this we have used the __"StandardScaler" technique__ to scaled down the values of these columns.

# %% [markdown]
# ## Handling Imbalanced Dataset [Using SMOTE]

# %%
df_new.value_counts('Class')
# Out:
# Class
# 0    284307
# 1       492
# dtype: int64

# %% [markdown]
# As We can see inthe above cell that the dataset is imbalanced. the count of __0 = 284315__ and the count of __1 = 492__ only.
#
# Now we are going to use the __SMOTE__ technique to balance the dataset.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)

X = df_new.drop('Class',axis=1)
y = df_new['Class']

X_res,y_res = sm.fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# 0    284307
# 1    284307
# Name: Class, dtype: int64

# %%
len(y_res)
# Out:
# 568614

# %%
len(X_res)
# Out:
# 568614

# %% [markdown]
# ## Train Test Split

# %%
X_res.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       0.262062    -1.996583 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.362073    -1.996583  1.191857  0.266151  0.166480  0.448154
# 2       1.234987    -1.996562 -1.358354 -1.340163  1.773209  0.379780
# 3       0.151108    -1.996562 -0.966272 -0.185226  1.792993 -0.863291
# 4      -0.076194    -1.996540 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V19       V20       V21  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.403993  0.251412 -0.018307
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.145783 -0.069083 -0.225775
# 2 -0.503198  1.800499  0.791461  0.247676  ... -2.261857  0.524980  0.247998
# 3 -0.010309  1.247203  0.237609  0.377436  ... -1.232622 -0.208038 -0.108300
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(
    X_res,y_res,test_size=0.2,random_state=42)

# %% [markdown]
# # Model Training

# %% [markdown]
# Here we are going to train multiple model. So that we can get to know that which model performs better and we can use that model for further use.
#
# So we are going to train the following models :
#
#     1. Logistic Regression
#     2. Naive Bayes
#     3. K-Nearest Neighbour
#     4. Decision Tree
#     5. Random Forest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

models = {
    'Logistic Regression':LogisticRegression(),
    'Naive Bayes Classifier':GaussianNB(),
    'KNN Classifier':KNeighborsClassifier(),
    'Decision Tree Classsifier':DecisionTreeClassifier(),
    'Random Fores Classifier ':RandomForestClassifier()
}


for i in range(len(list(models))):
    model = list(models.values())[i]
    print(list(models.keys())[i])
    print("\n")

    
    cv_scores = cross_val_score(model, X_train, y_train, cv=5)  
    print("Cross-validation scores:", cv_scores)
    print(f"Average CV accuracy for {list(models.keys())[i]}:", np.mean(cv_scores))


    # Training of the model
    model.fit(X_train, y_train)

    # predictions
    y_pred = model.predict(X_test)

    # Evaluation
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)

    
    print(f"Test set accuracy for {(list(models.keys())[i])}:", accuracy)
    print("Confusion Matrix:\n", conf_matrix)
    print("Classification Report:\n", class_report)
    print("\n" + "="*50 + "\n")
# Out:
# Logistic Regression
#
#
# Cross-validation scores: [0.94831774 0.94765768 0.94847106 0.94706413 0.94805338]
# Average CV accuracy for Logistic Regression: 0.9479127958017461
# Test set accuracy for Logistic Regression: 0.9477590285166589
# Confusion Matrix:
#  [[55298  1371]
#  [ 4570 52484]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     56669
#            1       0.97      0.92      0.95     57054
#
#     accuracy                           0.95    113723
#    macro avg       0.95      0.95      0.95    113723
# weighted avg       0.95      0.95      0.95    113723
#
#
# ...
#
# Naive Bayes Classifier
#
#
# Cross-validation scores: [0.91387023 0.91558399 0.91335268 0.91237442 0.914243  ]
# Average CV accuracy for Naive Bayes Classifier: 0.9138848647579991
# Test set accuracy for Naive Bayes Classifier: 0.9135706937031207
# Confusion Matrix:
#  [[55228  1441]
#  [ 8388 48666]]
# Classification Report:
# ...

# %% [markdown]
# Here we evaluated the performance of five distinct algorithms: Logistic Regression, Naive Bayes, K Nearest Neighbors, Decision Tree, and Random Forest. The assessment included accuracy metrics and cross-validation scores.
#
# __Logistic Regression:__
#
#     Accuracy: 94.78%
#     Cross Validation: 94.79%
#
# __Naive Bayes:__
#
#     Accuracy: 91.36%
#     Cross Validation: 91.39%
#
# __K Nearest Neighbors:__
#
#     Accuracy: 99.90%
#     Cross Validation: 99.89%
#
# __Decision Tree:__
#
#     Accuracy: 99.82%
#     Cross Validation: 99.78%
#
# __Random Forest:__
#
#     Accuracy: 99.99%
#     Cross Validation: 99.98%

# %% [markdown]
# # Fraud Detection Model Report

# %% [markdown]
# ## Objective:
# Build a machine learning model to effectively differentiate between fraudulent and non-fraudulent banking transactions. Achieve metrics of over 80% for accuracy, F1-score, and recall, considering the challenge of imbalanced data.

# %% [markdown]
# ## Methodology:
#
# __1. Data Understanding:__
#
#     Used the INFO() method to get the idea about the dataset.
#     Using DESCRIBE() method get the summary statistics for numerical feature including mean, std. dev., minimum, 25th percentile, 50th percentile, 75th percentile and maximum.
#
#
# __2. Data Preprocessing:__
#
#     Used Boxplot grapg to visually identify the outliers in features.
#
#
# __3. Handling Imbalanced Data:__
#
#     Recognized the imbalance in the target variable.
#     Using SMOTE technique to solved the problem of imbalanced dataset
#
#
# __4. Model Selection:__
#
#     Experimented with various machine learning models, including Logistic Regression, Naive Bayes, KNN Classifier, Decision Trees and Random Forests.
#
# __5. Model Training:__
#
#     Trained the model and use cross validation technique to reduce the overfitting and get the robust and generalized models.
#
#
# __6. Evaluation Metrics:__
#
#     To evaluate the model we have used the following metrics: Accuracy, confusion and classification report and get the value of model accuracy, f1 score, precision and recall.

# %% [markdown]
# ## __Observations__:
#
# The __Random Forest model__ gives the best performance, achieving the highest __ccuracy of 99.99%__ and an equally impressive __cross-validation score of 99.98%.__ This shows the robustness and generalization capabilities of the Random Forest algorithm in our specific context.

# %% [markdown]
# ## Results:
#
# __Random Forest Model:__
#
#     Accuracy: 99.99 %
#     F1-score: 100 %
#     Precision : 100 %
#     Recall: 100 %

# %% [markdown]
# ### The Random Forest model, coupled with SMOTE and CrossValidation, we achieved metrics of 99.99% accuracy, 100% F1-score, 100% precision and 100% recall meet the specified criteria.
